# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel('G:\《Python数据分析14天入门训练营》课程视频\作业中用的数据\课程3资料\豆瓣电影数据.xlsx')

# %%
df.head()#显示前5行
df.tail()#后5行
# Out:
#                                                       名字  投票人数  \
# 38733                                              神学院 S  46.0
# 38734                                              1935年  57.0
# 38735                                               血溅画屏  95.0
# 38736                                             魔窟中的幻想  51.0
# 38737  列宁格勒围困之星火战役 Блокада: Фильм 2: Ленинградский ме...  32.0
#
#                    类型    产地                 上映时间  时长    年代   评分 首映地点
# 38733           Adult    法国  1905-06-05 00:00:00  58  1983  8.6   美国
# 38734           喜剧/歌舞    美国  1935-03-15 00:00:00  98  1935  7.6   美国
# 38735  剧情/悬疑/犯罪/武侠/古装  中国大陆  1905-06-08 00:00:00  91  1986  7.1   美国
# 38736        惊悚/恐怖/儿童  中国大陆  1905-06-08 00:00:00  78  1986  8.0   美国
# 38737           剧情/战争    苏联  1905-05-30 00:00:00  97  1977  6.6   美国

# %%
df.iloc[0] #iloc行操作
# Out:
# 名字                   肖申克的救赎
# 投票人数                 692795
# 类型                    剧情/犯罪
# 产地                       美国
# 上映时间    1994-09-10 00:00:00
# 时长                      142
# 年代                     1994
# 评分                      9.6
# 首映地点                 多伦多电影节
# Name: 0, dtype: object

# %%
df.iloc[0:5]#显示0到4行，不包括5
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港

# %%
df.loc[0:5]#显示0到5行
# Out:
#        名字      投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795.0     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995.0  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855.0  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897.0     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523.0  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
# 5  泰坦尼克号   157074.0  剧情/爱情/灾难    美国  2012-04-10 00:00:00  194  2012  9.4
#
#      首映地点
# 0  多伦多电影节
# 1      美国
# 2     意大利
# 3   洛杉矶首映
# 4      香港
# 5    中国大陆

# %%
dit={'名字':'复仇联盟3','投票人数':'1234','类型':'科幻','产地':'美国','上映时间':'2018','时长':'112','年代':'2018','评分':'9.2','首映地点':'美国'}
s=pd.Series(dit)
s.name=38738
df=df.append(s)

# %%
df[-5:]#显示后5行
# Out:
#                                                       名字  投票人数  \
# 38734                                              1935年    57
# 38735                                               血溅画屏    95
# 38736                                             魔窟中的幻想    51
# 38737  列宁格勒围困之星火战役 Блокада: Фильм 2: Ленинградский ме...    32
# 38738                                              复仇联盟3  1234
#
#                    类型    产地                 上映时间   时长    年代   评分 首映地点
# 38734           喜剧/歌舞    美国  1935-03-15 00:00:00   98  1935  7.6   美国
# 38735  剧情/悬疑/犯罪/武侠/古装  中国大陆  1905-06-08 00:00:00   91  1986  7.1   美国
# 38736        惊悚/恐怖/儿童  中国大陆  1905-06-08 00:00:00   78  1986    8   美国
# 38737           剧情/战争    苏联  1905-05-30 00:00:00   97  1977  6.6   美国
# 38738              科幻    美国                 2018  112  2018  9.2   美国

# %%
df=df.drop({38738})#删除行
df[-5:]
# Out:
#                                                       名字 投票人数              类型  \
# 38733                                              神学院 S   46           Adult
# 38734                                              1935年   57           喜剧/歌舞
# 38735                                               血溅画屏   95  剧情/悬疑/犯罪/武侠/古装
# 38736                                             魔窟中的幻想   51        惊悚/恐怖/儿童
# 38737  列宁格勒围困之星火战役 Блокада: Фильм 2: Ленинградский ме...   32           剧情/战争
#
#          产地                 上映时间  时长    年代   评分 首映地点
# 38733    法国  1905-06-05 00:00:00  58  1983  8.6   美国
# 38734    美国  1935-03-15 00:00:00  98  1935  7.6   美国
# 38735  中国大陆  1905-06-08 00:00:00  91  1986  7.1   美国
# 38736  中国大陆  1905-06-08 00:00:00  78  1986    8   美国
# 38737    苏联  1905-05-30 00:00:00  97  1977  6.6   美国

# %%
df.columns#列操做
# Out:
# Index(['名字', '投票人数', '类型', '产地', '上映时间', '时长', '年代', '评分', '首映地点'], dtype='object')

# %%
df['名字'][:5]#前5列
# Out:
# 0    肖申克的救赎
# 1      控方证人
# 2     美丽人生
# 3      阿甘正传
# 4      霸王别姬
# Name: 名字, dtype: object

# %%
df[['名字','类型']][:5]
# Out:
#        名字        类型
# 0  肖申克的救赎     剧情/犯罪
# 1    控方证人  剧情/悬疑/犯罪
# 2   美丽人生   剧情/喜剧/爱情
# 3    阿甘正传     剧情/爱情
# 4    霸王别姬  剧情/爱情/同性

# %%
df['序号']=range(1,len(df)+1)#增加一列
df[:5]
# Out:
#        名字    投票人数        类型    产地                 上映时间   时长    年代   评分  \
# 0  肖申克的救赎  692795     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6
# 1    控方证人   42995  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5
# 2   美丽人生   327855  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5
# 3    阿甘正传  580897     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4
# 4    霸王别姬  478523  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4
#
#      首映地点  序号
# 0  多伦多电影节   1
# 1      美国   2
# 2     意大利   3
# 3   洛杉矶首映   4
# 4      香港   5

# %%
df=df.drop('序号',axis=1)#删除一列
df[:5]
# Out:
#        名字    投票人数        类型    产地                 上映时间   时长    年代   评分    首映地点
# 0  肖申克的救赎  692795     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6  多伦多电影节
# 1    控方证人   42995  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5      美国
# 2   美丽人生   327855  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5     意大利
# 3    阿甘正传  580897     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4   洛杉矶首映
# 4    霸王别姬  478523  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4      香港

# %%
df.loc[[1,3,5],['名字','评分']]#df.loc[[index],[colunm]]标签选择数据
# Out:
#        名字   评分
# 1    控方证人  9.5
# 3    阿甘正传  9.4
# 5  泰坦尼克号   9.4

# %%
df[df['产地']=='美国'][:5]#条件判断
# Out:
#        名字    投票人数        类型  产地                 上映时间   时长    年代   评分    首映地点
# 0  肖申克的救赎  692795     剧情/犯罪  美国  1994-09-10 00:00:00  142  1994  9.6  多伦多电影节
# 1    控方证人   42995  剧情/悬疑/犯罪  美国  1957-12-17 00:00:00  116  1957  9.5      美国
# 3    阿甘正传  580897     剧情/爱情  美国  1994-06-23 00:00:00  142  1994  9.4   洛杉矶首映
# 5  泰坦尼克号   157074  剧情/爱情/灾难  美国  2012-04-10 00:00:00  194  2012  9.4    中国大陆
# 6  辛德勒的名单  306904  剧情/历史/战争  美国  1993-11-30 00:00:00  195  1993  9.4   华盛顿首映

# %%
df[(df.产地=='美国')&(df.评分>9)][:5]#df[df['产地']=='美国']和df[(df.产地=='美国')]相同
# Out:
#        名字    投票人数        类型  产地                 上映时间   时长    年代   评分    首映地点
# 0  肖申克的救赎  692795     剧情/犯罪  美国  1994-09-10 00:00:00  142  1994  9.6  多伦多电影节
# 1    控方证人   42995  剧情/悬疑/犯罪  美国  1957-12-17 00:00:00  116  1957  9.5      美国
# 3    阿甘正传  580897     剧情/爱情  美国  1994-06-23 00:00:00  142  1994  9.4   洛杉矶首映
# 5  泰坦尼克号   157074  剧情/爱情/灾难  美国  2012-04-10 00:00:00  194  2012  9.4    中国大陆
# 6  辛德勒的名单  306904  剧情/历史/战争  美国  1993-11-30 00:00:00  195  1993  9.4   华盛顿首映

# %%
df[df['名字'].isnull()][:10]#df.isnull()判断缺失值
# Out:
#       名字  投票人数           类型  产地                 上映时间   时长    年代   评分 首映地点
# 231  NaN   144       纪录片/音乐  韩国  2011-02-02 00:00:00   90  2011  9.7   美国
# 361  NaN    80           短片  其他  1905-05-17 00:00:00    4  1964  5.7   美国
# 369  NaN  5315           剧情  日本  2004-07-10 00:00:00  111  2004  7.5   日本
# 372  NaN   263        短片/音乐  英国  1998-06-30 00:00:00   34  1998  9.2   美国
# 374  NaN    47           短片  其他  1905-05-17 00:00:00    3  1964  6.7   美国
# 375  NaN  1193        短片/音乐  法国  1905-07-01 00:00:00   10  2010  7.7   美国
# 411  NaN    32           短片  其他  1905-05-17 00:00:00    3  1964    7   美国
# 432  NaN  1081  剧情/动作/惊悚/犯罪  美国  2016-02-26 00:00:00  115  2016    6   美国
# 441  NaN   213           恐怖  美国  2007-03-06 00:00:00   83  2007  3.2   美国
# 448  NaN   110          纪录片  荷兰  2002-04-19 00:00:00   48  2000  9.3   美国

# %%
dit={'名字':'复仇联盟3','投票人数':'1234','类型':'科幻','产地':'美国','上映时间':'2018','时长':'112','年代':'2018','评分':np.nan,'首映地点':'美国'}
s=pd.Series(dit)
s.name=38738
df=df.append(s)
df[df['评分'].isnull()]
# Out:
#           名字  投票人数  类型  产地  上映时间   时长    年代   评分 首映地点
# 38738  复仇联盟3  1234  科幻  美国  2018  112  2018  NaN   美国

# %%
df['评分'].fillna(np.mean(df['评分']),inplace=True)#均值填充
df.tail()
# Out:
#                                                       名字  投票人数  \
# 38734                                              1935年    57
# 38735                                               血溅画屏    95
# 38736                                             魔窟中的幻想    51
# 38737  列宁格勒围困之星火战役 Блокада: Фильм 2: Ленинградский ме...    32
# 38738                                              复仇联盟3  1234
#
#                    类型    产地                 上映时间   时长    年代        评分 首映地点
# 38734           喜剧/歌舞    美国  1935-03-15 00:00:00   98  1935  7.600000   美国
# 38735  剧情/悬疑/犯罪/武侠/古装  中国大陆  1905-06-08 00:00:00   91  1986  7.100000   美国
# 38736        惊悚/恐怖/儿童  中国大陆  1905-06-08 00:00:00   78  1986  8.000000   美国
# 38737           剧情/战争    苏联  1905-05-30 00:00:00   97  1977  6.600000   美国
# 38738              科幻    美国                 2018  112  2018  6.935704   美国

# %%
df1=df.fillna('未知电影')
df1[df1['名字'].isnull()]
# Out:
# Empty DataFrame
# Columns: [名字, 投票人数, 类型, 产地, 上映时间, 时长, 年代, 评分, 首映地点]
# Index: []

# %%
df.dropna(inplace=True)#how='all'删除全为空值的行或列 inplace=True 覆盖之前的数据 axis=0 选择行或列代付【】

# %%
df['投票人数'].dtype#注意数据类型
# Out:
# dtype('float64')

# %%
df['投票人数']=df['投票人数'].astype('int')#浮点型数据转换成整数格式

# %%
df[:5]
# Out:
#        名字    投票人数        类型    产地                 上映时间   时长    年代   评分    首映地点
# 0  肖申克的救赎  692795     剧情/犯罪    美国  1994-09-10 00:00:00  142  1994  9.6  多伦多电影节
# 1    控方证人   42995  剧情/悬疑/犯罪    美国  1957-12-17 00:00:00  116  1957  9.5      美国
# 2   美丽人生   327855  剧情/喜剧/爱情   意大利  1997-12-20 00:00:00  116  1997  9.5     意大利
# 3    阿甘正传  580897     剧情/爱情    美国  1994-06-23 00:00:00  142  1994  9.4   洛杉矶首映
# 4    霸王别姬  478523  剧情/爱情/同性  中国大陆  1993-01-01 00:00:00  171  1993  9.4      香港

# %%
df['投票人数'].dtype
# Out:
# dtype('int32')

# %%
df[df['投票人数']%1==0]
# Out:
#                                                       名字    投票人数  \
# 0                                                 肖申克的救赎  692795
# 1                                                   控方证人   42995
# 2                                                  美丽人生   327855
# 3                                                   阿甘正传  580897
# 4                                                   霸王别姬  478523
# 5                                                 泰坦尼克号   157074
# 6                                                 辛德勒的名单  306904
# 7                  新世纪福音战士剧场版：Air/真心为你 新世紀エヴァンゲリオン劇場版 Ai   24355
# 8                         银魂完结篇：直到永远的万事屋 劇場版 銀魂 完結篇 万事屋よ   21513
# 9                                               这个杀手不太冷   662552
# 10                                                 灿烂人生    16807
# 11                                                 疯狂动物城  284652
# 12                              福音战士新剧场版：破 ヱヴァンゲリヲン新劇場版：   32524
# ...

# %%
df[df.投票人数 <0 ]
# Out:
#                                           名字  投票人数     类型    产地  \
# 19777                               皇家大贼 皇家大   -80  剧情/犯罪  中国香港
# 19786  日本的垃圾去中国大陆 にっぽんの“ゴミ” 大陆へ渡る ～中国式リサイクル錬   -80    纪录片    日本
# 19797                                    女教徒  -118     剧情    法国
#
#                       上映时间   时长    年代   评分 首映地点
# 19777  1985-05-31 00:00:00   60  1985  6.3   美国
# 19786  1905-06-26 00:00:00   60  2004  7.9   美国
# 19797  1966-05-06 00:00:00  135  1966  7.8   美国

# %%
df['年代']=df['年代'].astype('int')#发现异常值
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-7db608df647a> in <module>
# ----> 1 df['年代']=df['年代'].astype('int')
#
# E:\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# E:\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# ...

# %%
df[df.年代=='2008\u200e']
# Out:
#          名字  投票人数  类型    产地                 上映时间  时长     年代   评分 首映地点
# 15205  狂蟒惊魂   544  恐怖  中国大陆  2008-04-08 00:00:00  93  2008‎  2.7   美国

# %%
df.loc[15205,'年代']=2008#重新赋值

# %%
df['年代']=df['年代'].astype('int')

# %%
df.loc[15205]#查询行数据
# Out:
# 名字                     狂蟒惊魂
# 投票人数                    544
# 类型                       恐怖
# 产地                     中国大陆
# 上映时间    2008-04-08 00:00:00
# 时长                       93
# 年代                     2008
# 评分                      2.7
# 首映地点                     美国
# Name: 15205, dtype: object

# %%
df['年代'][:5]
# Out:
# 0    1994
# 1    1957
# 2    1997
# 3    1994
# 4    1993
# Name: 年代, dtype: int32

# %%
df['时长']=df['时长'].astype('int')#数据出错
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-83bf9b6fa2b3> in <module>
# ----> 1 df['时长']=df['时长'].astype('int')
#
# E:\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# E:\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# ...

# %%
df[df['时长']=='8U']#找到出错数据
# Out:
#              名字  投票人数      类型  产地                 上映时间  时长    年代   评分 首映地点
# 31644  一个被隔绝的世界    46  纪录片/短片  瑞典  2001-10-25 00:00:00  8U  1948  7.8   美国

# %%
df.drop([31644],inplace=True)#删除出错数据

# %%
df['时长']=df['时长'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-83bf9b6fa2b3> in <module>
# ----> 1 df['时长']=df['时长'].astype('int')
#
# E:\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# E:\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# ...

# %%
df[df['时长']=='12J']
# Out:
#          名字  投票人数   类型  产地                 上映时间   时长    年代   评分 首映地点
# 32949  渔业危机    41  纪录片  英国  2009-06-19 00:00:00  12J  2008  8.2  USA

# %%
df.drop([32949],inplace=True)

# %%
df['时长']=df['时长'].astype('int')

# %%
df=df[df.投票人数 >0]
df=df[df['投票人数']%1==0]#符合要求的正常值保存，即异常值删除

# %%
df.sort_values(by='投票人数')[:5]#排序 默认从小到大 ascending=False降序
# Out:
#                       名字  投票人数           类型  产地                 上映时间   时长  \
# 19804  女郎漫游仙境 ドレミファ娘の血は騒     5        喜剧/歌舞  日本  1985-11-03 00:00:00   80
# 19791             女教师 女教     8        剧情/犯罪  日本  1977-10-29 00:00:00  100
# 38055              逃出亚卡拉    12  剧情/动作/惊悚/犯罪  美国  1979-09-20 00:00:00  112
# 19820               女仆日记    12           剧情  法国  2015-04-01 00:00:00   96
# 1990              爱和一颗子弹    21        动作/犯罪  美国  2002-08-30 00:00:00   85
#
#          年代   评分 首映地点
# 19804  1985  6.7   日本
# 19791  1977  6.6   日本
# 38055  1979  7.8   美国
# 19820  2015  5.7   法国
# 1990   2002  7.0   美国

# %%
df.sort_values(by='年代')[:5]
# Out:
#             名字  投票人数           类型  产地                 上映时间  时长    年代   评分 首映地点
# 1700   朗德海花园场景   650           短片  英国           1888-10-14  60  1888  8.7   美国
# 14048     利兹大桥   126           短片  英国              1888-10  60  1888  7.2   美国
# 26170      恶作剧    51           短片  美国  1905-03-04 00:00:00  60  1890  4.8   美国
# 10627   可怜的比埃洛   176  喜剧/爱情/动画/短片  法国           1892-10-28  60  1892  7.5   法国
# 12374    更衣室之旁   148        动画/短片  法国              1894-12  60  1894  7.0   法国

# %%
df.sort_values(by=['评分','投票人数'],ascending=False)#多值排序 先评分，后数据
# Out:
#                                             名字   投票人数               类型    产地  \
# 9278                                  平安结祈 平安結    208               音乐    日本
# 13882                                      武之舞    128              纪录片  中国大陆
# 1110                                       NaN     76           科幻/纪录片    美国
# 23559                         未作回答的问题：伯恩斯坦哈佛六讲     61              纪录片    美国
# 35470                                      NaN     46           纪录片/音乐    韩国
# 25273                                索科洛夫：巴黎现场     43               音乐    法国
# 11479                                     公园现场    163               音乐    英国
# 35909                                      NaN    157           纪录片/音乐    美国
# 1289                                      Sant    143              脱口秀    日本
# 26025                             天使之声：自由童声合唱团     97           纪录片/音乐    美国
# 19428                              绿洲乐队海洋现场演唱会     82               音乐    英国
# ...

# %%
df.describe()#对dataframe中数据进行描述性统计
# Out:
#                 投票人数            时长            年代            评分
# count   38733.000000  38733.000000  38733.000000  38733.000000
# mean     6186.637079     89.052074   1998.789637      6.935618
# std     26145.110552     83.336808    253.208482      1.270138
# min         5.000000      1.000000   1888.000000      2.000000
# 25%        98.000000     60.000000   1990.000000      6.300000
# 50%       341.000000     92.000000   2005.000000      7.100000
# 75%      1741.000000    106.000000   2010.000000      7.800000
# max    692795.000000  11500.000000  39180.000000      9.900000

# %%
df[df['年代']>2018]
# Out:
#                    名字  投票人数   类型    产地                 上映时间   时长     年代   评分  \
# 13882             武之舞   128  纪录片  中国大陆  1997-02-01 00:00:00   60  34943  9.9
# 17115  妈妈回来吧-中国打工村的孩子    49  纪录片    日本  2007-04-08 00:00:00  109  39180  8.9
#
#       首映地点
# 13882   美国
# 17115   美国

# %%
df[df['时长']>1000]
# Out:
#             名字  投票人数        类型  产地                 上映时间     时长    年代   评分 首映地点
# 19690     怒海余生    54  剧情/家庭/冒险  美国  1937-09-01 00:00:00  11500  1937  7.9   美国
# 38730  喧闹村的孩子们    36        家庭  瑞典  1986-12-06 00:00:00   9200  1986  8.7   瑞典

# %%
df.drop(df[df['年代']>2018].index,inplace=True)
df.drop(df[df['时长']>1000].index,inplace=True)#删除异常数据

# %%
df.index=range(len(df))#删除数据后，重新排列index len()计数

# %%
df['投票人数'].max()#min 查看最值 sun总数求和
# Out:
# 692795

# %%
df['投票人数'].mean()#均值 median 中位数
# Out:
# 6187.269152314803

# %%
df['投票人数'].var()#方差 std 标准差
# Out:
# 683633538.7497708

# %%
df[['投票人数','评分']].corr()#相关系数  cov 协方差
# Out:
#           投票人数        评分
# 投票人数  1.000000  0.122957
# 评分    0.122957  1.000000

# %%
df['产地'].unique()#产地取值多少种
# Out:
# array(['美国', '意大利', '中国大陆', '日本', '法国', '英国', '韩国', '中国香港', '阿根廷', '德国',
#        '印度', '其他', '加拿大', '波兰', '泰国', '澳大利亚', '西班牙', '俄罗斯', '中国台湾', '荷兰',
#        '丹麦', '比利时', 'USA', '苏联', '墨西哥', '巴西', '瑞典', '西德'], dtype=object)

# %%
len(df['产地'].unique())
# Out:
# 28

# %%
df['产地'].replace('USA','美国',inplace=True)#重复值替换

# %%
df['产地'].replace(['西德','苏联'],['德国','俄罗斯'],inplace=True)#批量替换

# %%
df['产地'].unique()
# Out:
# array(['美国', '意大利', '中国大陆', '日本', '法国', '英国', '韩国', '中国香港', '阿根廷', '德国',
#        '印度', '其他', '加拿大', '波兰', '泰国', '澳大利亚', '西班牙', '俄罗斯', '中国台湾', '荷兰',
#        '丹麦', '比利时', '墨西哥', '巴西', '瑞典'], dtype=object)

# %%
df['年代'].unique()
# Out:
# array([1994, 1957, 1997, 1993, 2012, 2013, 2003, 2016, 2009, 2008, 2001,
#        1931, 1961, 2010, 2004, 1998, 1972, 1939, 2015, 1946, 2011, 1982,
#        1960, 2006, 1988, 2002, 1995, 1996, 1984, 2014, 1953, 2007, 2000,
#        1967, 1983, 1963, 1977, 1966, 1971, 1974, 1985, 1987, 1973, 1962,
#        1969, 1989, 1979, 1981, 1936, 1954, 1992, 1970, 1991, 2005, 1920,
#        1933, 1990, 1999, 1896, 1965, 1921, 1947, 1975, 1964, 1943, 1928,
#        1986, 1895, 1949, 1932, 1919, 1956, 1955, 1951, 1905, 1940, 1908,
#        1900, 1978, 1958, 1898, 1976, 1938, 1907, 1913, 1968, 1912, 1937,
#        1952, 1903, 1948, 1926, 1906, 1959, 1934, 1944, 1888, 1909, 1925,
#        1923, 1945, 1904, 1980, 1917, 1935, 1942, 1950, 1902, 1941, 1930,
#        1922, 1916, 1929, 1927, 1914, 1924, 1918, 1899, 1901, 1915, 1892,
#        1894, 1910, 1897, 1911, 1890], dtype=int64)

# %%
df['产地'].value_counts()#出现次数统计 默认从大到小
# Out:
# 美国      11978
# 日本       5051
# 中国大陆     3802
# 中国香港     2851
# 法国       2816
# 英国       2762
# 其他       1920
# 韩国       1351
# 德国       1032
# 意大利       749
# 加拿大       723
# 中国台湾      618
# 俄罗斯       477
# 西班牙       447
# 印度        357
# 澳大利亚      300
# 泰国        294
# 丹麦        198
# 瑞典        192
# 波兰        181
# 荷兰        155
# 比利时       139
# 墨西哥       119
# 阿根廷       116
# 巴西        101
# Name: 产地, dtype: int64

# %%
df.to_excel('movie_date2.xlsx')#数据保存

# %%
#数据透视 pivot_table

# %%
pd.set_option('max_columns',100)
pd.set_option('max_row',500)
#设置最大显示行和列

# %%
pd.pivot_table(df,index=['年代'])#以年代为索引分类
# Out:
#               投票人数         时长        评分
# 年代
# 1888    388.000000  60.000000  7.950000
# 1890     51.000000  60.000000  4.800000
# 1892    176.000000  60.000000  7.500000
# 1894    112.666667  60.000000  6.633333
# 1895    959.875000  60.000000  7.575000
# 1896    984.250000  60.000000  7.037500
# 1897     67.000000  60.000000  6.633333
# 1898    578.500000  60.000000  7.450000
# 1899     71.000000   9.500000  6.900000
# 1900    175.285714  36.714286  7.228571
# 1901    164.500000  47.250000  7.250000
# 1902   1934.166667  34.666667  7.483333
# 1903    295.625000  29.625000  6.968750
# 1904    195.875000  41.250000  7.212500
# 1905    332.600000  43.800000  6.820000
# 1906    189.857143  30.571429  7.342857
# 1907    213.600000  31.800000  7.020000
# 1908    258.833333  34.166667  7.150000
# 1909     58.600000  20.600000  7.560000
# 1910    105.200000  41.800000  6.940000
# 1911    240.000000  25.750000  7.375000
# 1912    152.200000  16.400000  7.920000
# ...

# %%
pd.pivot_table(df,index=["年代","产地"])#使用多个索引
# Out:
#                    投票人数          时长        评分
# 年代   产地
# 1888 英国      388.000000   60.000000  7.950000
# 1890 美国       51.000000   60.000000  4.800000
# 1892 法国      176.000000   60.000000  7.500000
# 1894 法国      148.000000   60.000000  7.000000
#      美国       95.000000   60.000000  6.450000
# 1895 法国      959.875000   60.000000  7.575000
# 1896 法国     1874.250000   60.000000  7.650000
#      美国       55.666667   60.000000  6.366667
#      英国      210.000000   60.000000  6.600000
# 1897 法国       67.000000   60.000000  6.633333
# 1898 法国      991.000000   60.000000  8.500000
#      英国      166.000000   60.000000  6.400000
# 1899 法国       71.000000    9.500000  6.900000
# 1900 法国       52.000000    5.666667  7.100000
#      美国      212.500000   60.000000  7.450000
#      英国      323.000000   60.000000  7.200000
# 1901 法国      142.000000    9.000000  7.700000
#      英国      172.000000   60.000000  7.100000
# 1902 法国     3818.000000   26.000000  8.066667
# ...

# %%
pd.pivot_table(df,index=["年代","产地"],values=["评分"])#指定需要项的数据
# Out:
#                  评分
# 年代   产地
# 1888 英国    7.950000
# 1890 美国    4.800000
# 1892 法国    7.500000
# 1894 法国    7.000000
#      美国    6.450000
# 1895 法国    7.575000
# 1896 法国    7.650000
#      美国    6.366667
#      英国    6.600000
# 1897 法国    6.633333
# 1898 法国    8.500000
#      英国    6.400000
# 1899 法国    6.900000
# 1900 法国    7.100000
#      美国    7.450000
#      英国    7.200000
# 1901 法国    7.700000
#      英国    7.100000
# 1902 法国    8.066667
#      美国    6.900000
# 1903 法国    6.960000
#      美国    6.850000
#      英国    7.250000
# 1904 法国    7.500000
#      美国    5.200000
# 1905 中国大陆  8.400000
#      美国    5.766667
#      英国    8.400000
# 1906 意大利   7.000000
#      法国    7.033333
#      美国    7.750000
#      英国    7.800000
# 1907 法国    7.020000
# 1908 法国    6.966667
#      美国    6.950000
#      西班牙   8.100000
# 1909 美国    7.560000
# 1910 法国    6.533333
#      美国    7.550000
# 1911 意大利   8.200000
#      美国    7.450000
#      荷兰    6.400000
# 1912 俄罗斯   8.100000
#      法国    7.750000
# ...

# %%
pd.pivot_table(df,index=["年代","产地"],values=["投票人数"],aggfunc=np.sum)#制定函数
# Out:
#               投票人数
# 年代   产地
# 1888 英国        776
# 1890 美国         51
# 1892 法国        176
# 1894 法国        148
#      美国        190
# 1895 法国       7679
# 1896 法国       7497
#      美国        167
#      英国        210
# 1897 法国        201
# 1898 法国        991
#      英国        166
# 1899 法国        142
# 1900 法国        156
#      美国        425
#      英国        646
# 1901 法国        142
#      英国        516
# 1902 法国      11454
#      美国        151
# 1903 法国        816
#      美国       3298
#      英国        616
# 1904 法国       1524
#      美国         43
# 1905 中国大陆      137
#      美国        137
#      英国       1389
# 1906 意大利        37
#      法国        232
#      美国        851
#      英国        209
# 1907 法国       1068
# 1908 法国       1376
#      美国         67
#      西班牙       110
# 1909 美国        293
# 1910 法国        236
#      美国        290
# 1911 意大利       297
#      美国        598
#      荷兰         65
# 1912 俄罗斯       511
#      法国        143
#      美国        107
# 1913 俄罗斯        54
# ...

# %%
pd.pivot_table(df,index=['产地'],values=['投票人数','评分'])#对产地实现数据聚合和总结
# Out:
#               投票人数        评分
# 产地
# 中国台湾   8474.864078  7.066667
# 中国大陆  10898.293793  6.064703
# 中国香港   8167.446159  6.474114
# 丹麦     1993.858586  7.245960
# 俄罗斯    1019.134172  7.554507
# 其他     1590.686979  7.237448
# 加拿大    1915.304288  6.733610
# 印度     3210.843137  6.872269
# 墨西哥    1173.218487  7.087395
# 巴西     3536.000000  7.262376
# 德国     2597.851744  7.198062
# 意大利    3340.740988  7.179306
# 日本     3563.782815  7.194476
# 比利时    1230.122302  7.217986
# 法国     3627.118608  7.238885
# 波兰      881.640884  7.441989
# 泰国     5322.724490  6.109184
# 澳大利亚   4719.043333  6.978000
# 瑞典     1510.817708  7.413021
# 美国     8499.433628  6.946861
# 英国     4797.089790  7.526937
# 荷兰      934.425806  7.190323
# 西班牙    3326.024609  7.024385
# 阿根廷    2226.474138  7.273276
# 韩国     6484.885270  6.362990

# %%
pd.pivot_table(df,index=['产地'],values=['投票人数','评分'],aggfunc=[np.sum,np.mean])
# Out:
#             sum                   mean
#            投票人数       评分          投票人数        评分
# 产地
# 中国台湾    5237466   4367.2   8474.864078  7.066667
# 中国大陆   41435313  23058.0  10898.293793  6.064703
# 中国香港   23285389  18457.7   8167.446159  6.474114
# 丹麦       394784   1434.7   1993.858586  7.245960
# 俄罗斯      486127   3603.5   1019.134172  7.554507
# 其他      3054119  13895.9   1590.686979  7.237448
# 加拿大     1384765   4868.4   1915.304288  6.733610
# 印度      1146271   2453.4   3210.843137  6.872269
# 墨西哥      139613    843.4   1173.218487  7.087395
# 巴西       357136    733.5   3536.000000  7.262376
# 德国      2680983   7428.4   2597.851744  7.198062
# 意大利     2502215   5377.3   3340.740988  7.179306
# 日本     18000667  36339.3   3563.782815  7.194476
# 比利时      170987   1003.3   1230.122302  7.217986
# 法国     10213966  20384.7   3627.118608  7.238885
# 波兰       159577   1347.0    881.640884  7.441989
# 泰国      1564881   1796.1   5322.724490  6.109184
# ...

# %%
 pd.pivot_table(df,index=['产地'],aggfunc=[np.sum,np.mean],fill_value=0)#fill_value填充nan为0
# Out:
#            sum                                      mean                \
#             年代       投票人数       时长       评分           年代          投票人数
# 产地
# 中国台湾   1235388    5237466    53925   4367.2  1999.009709   8474.864078
# 中国大陆   7621488   41435313   309608  23058.0  2004.599684  10898.293793
# 中国香港   5676627   23285389   252431  18457.7  1991.100316   8167.446159
# 丹麦      395820     394784    17444   1434.7  1999.090909   1993.858586
# 俄罗斯     946797     486127    45753   3603.5  1984.899371   1019.134172
# 其他     3837588    3054119   167168  13895.9  1998.743750   1590.686979
# 加拿大    1447780    1384765    57919   4868.4  2002.461964   1915.304288
# 印度      716133    1146271    43203   2453.4  2005.974790   3210.843137
# 墨西哥     237145     139613    10929    843.4  1992.815126   1173.218487
# 巴西      201987     357136     8869    733.5  1999.871287   3536.000000
# 德国     2059937    2680983    95008   7428.4  1996.062984   2597.851744
# ...

# %%
pd.pivot_table(df,index=['产地'],aggfunc=[np.sum,np.mean],fill_value=0,margins=True)#margins=True计算总和
# Out:
#            sum                                       mean                \
#             年代       投票人数       时长        评分           年代          投票人数
# 产地
# 中国台湾   1235388    5237466    53925    4367.2  1999.009709   8474.864078
# 中国大陆   7621488   41435313   309608   23058.0  2004.599684  10898.293793
# 中国香港   5676627   23285389   252431   18457.7  1991.100316   8167.446159
# 丹麦      395820     394784    17444    1434.7  1999.090909   1993.858586
# 俄罗斯     946797     486127    45753    3603.5  1984.899371   1019.134172
# 其他     3837588    3054119   167168   13895.9  1998.743750   1590.686979
# 加拿大    1447780    1384765    57919    4868.4  2002.461964   1915.304288
# 印度      716133    1146271    43203    2453.4  2005.974790   3210.843137
# 墨西哥     237145     139613    10929     843.4  1992.815126   1173.218487
# 巴西      201987     357136     8869     733.5  1999.871287   3536.000000
# 德国     2059937    2680983    95008    7428.4  1996.062984   2597.851744
# ...

# %%
pd.pivot_table(df,index=['产地'],values=['投票人数','评分'],aggfunc={'投票人数':np.sum,'评分':np.mean},fill_value=0)
#对不同值执行不同函数
# Out:
#            投票人数        评分
# 产地
# 中国台湾    5237466  7.066667
# 中国大陆   41435313  6.064703
# 中国香港   23285389  6.474114
# 丹麦       394784  7.245960
# 俄罗斯      486127  7.554507
# 其他      3054119  7.237448
# 加拿大     1384765  6.733610
# 印度      1146271  6.872269
# 墨西哥      139613  7.087395
# 巴西       357136  7.262376
# 德国      2680983  7.198062
# 意大利     2502215  7.179306
# 日本     18000667  7.194476
# 比利时      170987  7.217986
# 法国     10213966  7.238885
# 波兰       159577  7.441989
# 泰国      1564881  6.109184
# 澳大利亚    1415713  6.978000
# 瑞典       290077  7.413021
# 美国    101806216  6.946861
# 英国     13249562  7.526937
# 荷兰       144836  7.190323
# 西班牙     1486733  7.024385
# 阿根廷      258271  7.273276
# 韩国      8761080  6.362990

# %%
pd.pivot_table(df,index=['年代'],values=['投票人数','评分'],aggfunc={'投票人数':np.sum,'评分':np.mean},fill_value=0)
# Out:
#           投票人数        评分
# 年代
# 1888       776  7.950000
# 1890        51  4.800000
# 1892       176  7.500000
# 1894       338  6.633333
# 1895      7679  7.575000
# 1896      7874  7.037500
# 1897       201  6.633333
# 1898      1157  7.450000
# 1899       142  6.900000
# 1900      1227  7.228571
# 1901       658  7.250000
# 1902     11605  7.483333
# 1903      4730  6.968750
# 1904      1567  7.212500
# 1905      1663  6.820000
# 1906      1329  7.342857
# 1907      1068  7.020000
# 1908      1553  7.150000
# 1909       293  7.560000
# 1910       526  6.940000
# 1911       960  7.375000
# 1912       761  7.920000
# 1913       529  6.862500
# 1914      2728  6.473077
# 1915      6298  7.260000
# 1916      7364  7.758333
# 1917      1493  7.075000
# 1918      4285  7.200000
# 1919      3597  7.490000
# 1920      8911  7.492857
# 1921     16056  7.750000
# 1922     16876  7.804545
# 1923      7668  7.883333
# 1924     10410  8.053571
# 1925     27607  7.788000
# ...

# %%
table=pd.pivot_table(df,index=['年代'],values=['投票人数','评分'],aggfunc={'投票人数':np.sum,'评分':np.mean},fill_value=0)

# %%
type(table)
# Out:
# pandas.core.frame.DataFrame

# %%
table[table.index==1994]
# Out:
#          投票人数        评分
# 年代
# 1994  5670752  7.262348

# %%
table.sort_values('评分',ascending=False)#年代平均分排序
# Out:
#           投票人数        评分
# 年代
# 1924     10410  8.053571
# 1888       776  7.950000
# 1928     16193  7.945000
# 1912       761  7.920000
# 1923      7668  7.883333
# 1922     16876  7.804545
# 1925     27607  7.788000
# 1926     10203  7.773913
# 1916      7364  7.758333
# 1927     20163  7.751724
# 1921     16056  7.750000
# 1961    325057  7.744118
# 1952    128198  7.743678
# 1938     20976  7.736842
# 1962    282013  7.704895
# 1954    222385  7.702941
# 1945     48462  7.673469
# 1948    103226  7.657471
# 1950    169862  7.655263
# 1957    318173  7.652336
# 1949     57110  7.646067
# 1951     75532  7.636709
# 1936     87928  7.635000
# 1943     42342  7.615789
# 1946     61033  7.606780
# 1956    155027  7.600000
# 1955    228130  7.580000
# 1965    324074  7.576074
# 1937     77431  7.575510
# 1895      7679  7.575000
# 1959    220809  7.571875
# 1940    216401  7.571795
# 1960    189462  7.569466
# 1953    421178  7.567045
# 1909       293  7.560000
# ...

# %%
#多个索引汇总
